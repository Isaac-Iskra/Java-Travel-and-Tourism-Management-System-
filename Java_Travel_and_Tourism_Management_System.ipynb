# %%
import java.util.Scanner;

public class TourismAndTravelManagementSystem {
    public static void main(String[] args) {
        Scanner input = new Scanner(System.in);

        System.out.println("Welcome to the Tourism and Travel Management System!");

        // Initialize variables
        int choice;
        String destination = "";
        int duration = 0;
        int numPeople = 0;

        // Loop until user quits
        while (true) {
            System.out.println("Please choose an option:");
            System.out.println("1. Search for a destination");
            System.out.println("2. Book a tour");
            System.out.println("3. Cancel a tour");
            System.out.println("4. Exit");

            choice = input.nextInt();

            switch (choice) {
                case 1:
                    System.out.println("Enter a destination:");
                    destination = input.next();
                    System.out.println("Enter the duration of the tour (in days):");
                    duration = input.nextInt();
                    System.out.println("Enter the number of people:");
                    numPeople = input.nextInt();
                    System.out.println("Searching for available tours to " + destination + "...");
                    // Call method to search for available tours
                    break;
                case 2:
                    System.out.println("Enter your name:");
                    String name = input.next();
                    System.out.println("Enter your contact number:");
                    String contactNumber = input.next();
                    System.out.println("Enter your email address:");
                    String email = input.next();
                    System.out.println("Enter the name of the tour you want to book:");
                    String tourName = input.next();
                    System.out.println("Enter the date of the tour (in DD/MM/YYYY format):");
                    String tourDate = input.next();
                    System.out.println("Booking tour...");
                    // Call method to book a tour
                    break;
                case 3:
                    System.out.println("Enter your name:");
                    name = input.next();
                    System.out.println("Enter your contact number:");
                    contactNumber = input.next();
                    System.out.println("Enter your email address:");
                    email = input.next();
                    System.out.println("Enter the name of the tour you want to cancel:");
                    tourName = input.next();
                    System.out.println("Enter the date of the tour (in DD/MM/YYYY format):");
                    tourDate = input.next();
                    System.out.println("Canceling tour...");
                    // Call method to cancel a tour
                    break;
                case 4:
                    System.out.println("Thank you for using the Tourism and Travel Management System!");
                    System.exit(0);
                default:
                    System.out.println("Invalid choice, please try again.");
            }
        }
    }
}
